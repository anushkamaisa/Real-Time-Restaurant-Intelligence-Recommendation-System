# %%
# Setup and execute the updated graph analysis code in this notebook
import warnings
warnings.filterwarnings('ignore', category=UserWarning, message=r'.*DataFrame\.sql_ctx is an internal property.*')

from spark.graph_analysis import run_graph_analysis

# Run the graph analysis script and capture output
run_graph_analysis()
